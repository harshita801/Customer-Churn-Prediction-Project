# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn (1).csv")

# %%
df.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 7038              Yes         Yes         Yes             Yes        One year
# 7039              Yes          No         Yes             Yes        One year
# 7040               No          No          No              No  Month-to-month
# 7041               No          No          No              No  Month-to-month
# 7042              Yes         Yes         Yes             Yes        Two year
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 7038              Yes               Mailed check          84.80        1990.5
# 7039              Yes    Credit card (automatic)         103.20        7362.9
# 7040              Yes           Electronic check          29.60        346.45
# 7041              Yes               Mailed check          74.40         306.6
# 7042              Yes  Bank transfer (automatic)         105.65        6844.5
#
#      Churn
# 7038    No
# 7039    No
# 7040    No
# 7041   Yes
# 7042    No
#
# [5 rows x 21 columns]

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
df.drop("customerID", axis=1, inplace=True)

# %%
df['Churn']=df['Churn'].map({'Yes':1,'No':0})

# %%
df['Churn'].value_counts()
# Out:
# Churn
# 0    5174
# 1    1869
# Name: count, dtype: int64

# %%
df['gender']=df['gender'].map({'Male':1,'Female':0})

# %%
df['gender'].value_counts()
# Out:
# gender
# 1    3555
# 0    3488
# Name: count, dtype: int64

# %%
df['SeniorCitizen'].value_counts()
# Out:
# SeniorCitizen
# 0    5901
# 1    1142
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df['Contract'].value_counts()
# Out:
# Contract
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: count, dtype: int64

# %%
df['Dependents'].value_counts()
# Out:
# Dependents
# No     4933
# Yes    2110
# Name: count, dtype: int64

# %%
df['Dependents']=df['Dependents'].map({'Yes':1,'No':0})

# %%
df['Dependents'].value_counts()
# Out:
# Dependents
# 0    4933
# 1    2110
# Name: count, dtype: int64

# %%
df['PhoneService'].value_counts()
# Out:
# PhoneService
# Yes    6361
# No      682
# Name: count, dtype: int64

# %%
df['PhoneService']=df['PhoneService'].map({'Yes':1,'No':0})

# %%
df['MultipleLines'].value_counts()
# Out:
# MultipleLines
# No                  3390
# Yes                 2971
# No phone service     682
# Name: count, dtype: int64

# %%
df['Partner'].value_counts()
# Out:
# Partner
# No     3641
# Yes    3402
# Name: count, dtype: int64

# %%
df['Partner']=df['Partner'].map({'Yes':1,'No':0})

# %%
df['InternetService'].value_counts()
# Out:
# InternetService
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: count, dtype: int64

# %%
df['MonthlyCharges'].value_counts()
# Out:
# MonthlyCharges
# 20.05     61
# 19.85     45
# 19.95     44
# 19.90     44
# 20.00     43
#           ..
# 23.65      1
# 114.70     1
# 43.65      1
# 87.80      1
# 78.70      1
# Name: count, Length: 1585, dtype: int64

# %%
df['OnlineBackup'].value_counts()
# Out:
# OnlineBackup
# No                     3088
# Yes                    2429
# No internet service    1526
# Name: count, dtype: int64

# %%
df['OnlineSecurity'].value_counts()
# Out:
# OnlineSecurity
# No                     3498
# Yes                    2019
# No internet service    1526
# Name: count, dtype: int64

# %%
df['PaperlessBilling'].value_counts()
# Out:
# PaperlessBilling
# Yes    4171
# No     2872
# Name: count, dtype: int64

# %%
df['PaperlessBilling']=df['PaperlessBilling'].map({'Yes':1,'No':0})

# %%
df['PaymentMethod'].value_counts()
# Out:
# PaymentMethod
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: count, dtype: int64

# %%
df['StreamingMovies'].value_counts()
# Out:
# StreamingMovies
# No                     2785
# Yes                    2732
# No internet service    1526
# Name: count, dtype: int64

# %%
df['StreamingTV'].value_counts()
# Out:
# StreamingTV
# No                     2810
# Yes                    2707
# No internet service    1526
# Name: count, dtype: int64

# %%
df['TechSupport'].value_counts()
# Out:
# TechSupport
# No                     3473
# Yes                    2044
# No internet service    1526
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import OneHotEncoder
df=pd.get_dummies(df,columns=['MultipleLines',
                              'OnlineBackup',
                              'OnlineSecurity',
                              'PaymentMethod',
                              'StreamingMovies',
                              'StreamingTV',
                              'TechSupport',
                              'Contract',
                              'InternetService',
                              'DeviceProtection',
                              ],drop_first=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 31 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   gender                                 7043 non-null   int64
#  1   SeniorCitizen                          7043 non-null   int64
#  2   Partner                                7043 non-null   int64
#  3   Dependents                             7043 non-null   int64
#  4   tenure                                 7043 non-null   int64
#  5   PhoneService                           7043 non-null   int64
#  6   PaperlessBilling                       7043 non-null   int64
#  7   MonthlyCharges                         7043 non-null   float64
#  8   TotalCharges                           7043 non-null   object
#  9   Churn                                  7043 non-null   int64
#  10  MultipleLines_No phone service         7043 non-null   bool
#  11  MultipleLines_Yes                      7043 non-null   bool
#  12  OnlineBackup_No internet service       7043 non-null   bool
#  13  OnlineBackup_Yes                       7043 non-null   bool
#  14  OnlineSecurity_No internet service     7043 non-null   bool
#  15  OnlineSecurity_Yes                     7043 non-null   bool
#  16  PaymentMethod_Credit card (automatic)  7043 non-null   bool
#  17  PaymentMethod_Electronic check         7043 non-null   bool
#  18  PaymentMethod_Mailed check             7043 non-null   bool
#  19  StreamingMovies_No internet service    7043 non-null   bool
#  20  StreamingMovies_Yes                    7043 non-null   bool
#  21  StreamingTV_No internet service        7043 non-null   bool
#  22  StreamingTV_Yes                        7043 non-null   bool
#  23  TechSupport_No internet service        7043 non-null   bool
#  24  TechSupport_Yes                        7043 non-null   bool
#  25  Contract_One year                      7043 non-null   bool
#  26  Contract_Two year                      7043 non-null   bool
#  27  InternetService_Fiber optic            7043 non-null   bool
#  28  InternetService_No                     7043 non-null   bool
#  29  DeviceProtection_No internet service   7043 non-null   bool
#  30  DeviceProtection_Yes                   7043 non-null   bool
# dtypes: bool(21), float64(1), int64(8), object(1)
# memory usage: 694.8+ KB

# %% [markdown]
# ### Converting bool to int

# %%
bool_cols = df.select_dtypes(include='bool').columns
df[bool_cols] = df[bool_cols].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 31 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   gender                                 7043 non-null   int64
#  1   SeniorCitizen                          7043 non-null   int64
#  2   Partner                                7043 non-null   int64
#  3   Dependents                             7043 non-null   int64
#  4   tenure                                 7043 non-null   int64
#  5   PhoneService                           7043 non-null   int64
#  6   PaperlessBilling                       7043 non-null   int64
#  7   MonthlyCharges                         7043 non-null   float64
#  8   TotalCharges                           7043 non-null   object
#  9   Churn                                  7043 non-null   int64
#  10  MultipleLines_No phone service         7043 non-null   int64
#  11  MultipleLines_Yes                      7043 non-null   int64
#  12  OnlineBackup_No internet service       7043 non-null   int64
#  13  OnlineBackup_Yes                       7043 non-null   int64
#  14  OnlineSecurity_No internet service     7043 non-null   int64
#  15  OnlineSecurity_Yes                     7043 non-null   int64
#  16  PaymentMethod_Credit card (automatic)  7043 non-null   int64
#  17  PaymentMethod_Electronic check         7043 non-null   int64
#  18  PaymentMethod_Mailed check             7043 non-null   int64
#  19  StreamingMovies_No internet service    7043 non-null   int64
#  20  StreamingMovies_Yes                    7043 non-null   int64
#  21  StreamingTV_No internet service        7043 non-null   int64
#  22  StreamingTV_Yes                        7043 non-null   int64
#  23  TechSupport_No internet service        7043 non-null   int64
#  24  TechSupport_Yes                        7043 non-null   int64
#  25  Contract_One year                      7043 non-null   int64
#  26  Contract_Two year                      7043 non-null   int64
#  27  InternetService_Fiber optic            7043 non-null   int64
#  28  InternetService_No                     7043 non-null   int64
#  29  DeviceProtection_No internet service   7043 non-null   int64
#  30  DeviceProtection_Yes                   7043 non-null   int64
# dtypes: float64(1), int64(29), object(1)
# memory usage: 1.7+ MB

# %%
print(df['TotalCharges'].dtype)
# Out:
# object

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

# %%
print(df['TotalCharges'].isnull().sum())
# Out:
# 11

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7032 entries, 0 to 7042
# Data columns (total 31 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   gender                                 7032 non-null   int64
#  1   SeniorCitizen                          7032 non-null   int64
#  2   Partner                                7032 non-null   int64
#  3   Dependents                             7032 non-null   int64
#  4   tenure                                 7032 non-null   int64
#  5   PhoneService                           7032 non-null   int64
#  6   PaperlessBilling                       7032 non-null   int64
#  7   MonthlyCharges                         7032 non-null   float64
#  8   TotalCharges                           7032 non-null   float64
#  9   Churn                                  7032 non-null   int64
#  10  MultipleLines_No phone service         7032 non-null   int64
#  11  MultipleLines_Yes                      7032 non-null   int64
#  12  OnlineBackup_No internet service       7032 non-null   int64
#  13  OnlineBackup_Yes                       7032 non-null   int64
#  14  OnlineSecurity_No internet service     7032 non-null   int64
#  15  OnlineSecurity_Yes                     7032 non-null   int64
#  16  PaymentMethod_Credit card (automatic)  7032 non-null   int64
#  17  PaymentMethod_Electronic check         7032 non-null   int64
#  18  PaymentMethod_Mailed check             7032 non-null   int64
#  19  StreamingMovies_No internet service    7032 non-null   int64
#  20  StreamingMovies_Yes                    7032 non-null   int64
#  21  StreamingTV_No internet service        7032 non-null   int64
#  22  StreamingTV_Yes                        7032 non-null   int64
#  23  TechSupport_No internet service        7032 non-null   int64
#  24  TechSupport_Yes                        7032 non-null   int64
#  25  Contract_One year                      7032 non-null   int64
#  26  Contract_Two year                      7032 non-null   int64
#  27  InternetService_Fiber optic            7032 non-null   int64
#  28  InternetService_No                     7032 non-null   int64
#  29  DeviceProtection_No internet service   7032 non-null   int64
#  30  DeviceProtection_Yes                   7032 non-null   int64
# dtypes: float64(2), int64(29)
# memory usage: 1.7 MB

# %%
plt.Figure(figsize=(20,10))
sns.heatmap(df.corr(), cmap='coolwarm')
# Out:
# <Axes: >

# %%
corr=df.corr(numeric_only=True)
corr['Churn'].sort_values(ascending=False)
# Out:
# Churn                                    1.000000
# InternetService_Fiber optic              0.307463
# PaymentMethod_Electronic check           0.301455
# MonthlyCharges                           0.192858
# PaperlessBilling                         0.191454
# SeniorCitizen                            0.150541
# StreamingTV_Yes                          0.063254
# StreamingMovies_Yes                      0.060860
# MultipleLines_Yes                        0.040033
# PhoneService                             0.011691
# gender                                  -0.008545
# MultipleLines_No phone service          -0.011691
# DeviceProtection_Yes                    -0.066193
# OnlineBackup_Yes                        -0.082307
# PaymentMethod_Mailed check              -0.090773
# PaymentMethod_Credit card (automatic)   -0.134687
# Partner                                 -0.149982
# Dependents                              -0.163128
# TechSupport_Yes                         -0.164716
# OnlineSecurity_Yes                      -0.171270
# Contract_One year                       -0.178225
# TotalCharges                            -0.199484
# StreamingMovies_No internet service     -0.227578
# StreamingTV_No internet service         -0.227578
# OnlineSecurity_No internet service      -0.227578
# TechSupport_No internet service         -0.227578
# OnlineBackup_No internet service        -0.227578
# InternetService_No                      -0.227578
# DeviceProtection_No internet service    -0.227578
# Contract_Two year                       -0.301552
# tenure                                  -0.354049
# Name: Churn, dtype: float64

# %%
df.to_csv("Customer-Churn_processed (1).csv",index = False)
